# %% [markdown]
# # CRS – Concept Recommendation System
# ### Time-Aware Learning Assistant for Engineering Students
#
# **Student Name:** Harish Joshi
# **Project Type:** Course Project
# **Domain:** Content Recommendation System (CRS)
# **Tools Used:** Python, Sentence Transformers, ChromaDB, Flask
#
# ---
#
# ## Abstract
#
# This project implements a Concept Recommendation System (CRS) that explains
# engineering topics based on the time available to a learner.
# The system retrieves relevant knowledge chunks from a vector database and
# constructs a structured, exam-oriented explanation.
# Related topics are also suggested to guide further learning.

# %% [markdown]
# ## Problem Statement
#
# Engineering students often struggle to revise concepts efficiently due to:
# - Unstructured study material
# - Excessive jargon
# - Lack of time-based explanations
# - Difficulty finding related concepts
#
# Traditional search engines return large amounts of unfiltered information, which is not optimized for exam-oriented revision.
#
# ### Objective
#
# To design a system that:
# - Explains a concept clearly within a given time limit
# - Structures the explanation into logical sections
# - Suggests relevant related topics automatically
# - Uses semantic similarity instead of keyword matching

# %% [markdown]
# ## System Architecture
#
# The CRS system consists of four main components:
#
# 1. **Raw Content Layer**
#    - Topic-wise text files stored locally
#    - Example: MOSFETs, Rectifiers, Counters, etc.
#
# 2. **Chunking & Indexing Layer**
#    - Text is split into meaningful chunks
#    - Each chunk is tagged with a learning stage
#    - Sentence embeddings are generated
#    - Stored in a vector database (ChromaDB)
#
# 3. **Recommender Engine**
#    - User query is embedded
#    - Relevant chunks are retrieved semantically
#    - Explanation is built based on available time
#    - Related topics are ranked and suggested
#
# 4. **User Interface**
#    - Web-based UI (Flask + HTML)
#    - Allows topic input and time selection

# %% [markdown]
# ## Technologies Used
#
# - **Python** – Core programming language
# - **Sentence Transformers** – Semantic embeddings
# - **ChromaDB** – Vector database for storage and retrieval
# - **Flask** – Backend API
# - **HTML** – Frontend UI
# - **Jupyter Notebook** – Documentation and demonstration
#
# ### Key Design Decisions
#
# - Vector similarity instead of keyword search
# - Time-aware explanation length
# - Stage-wise structured explanations
# - Incremental database updates

# %%
import sys
import os

# Add backend folder to Python path
sys.path.append(os.path.abspath("backend"))

print("Backend path added successfully.")
# Out:
# Backend path added successfully.

# %%
# Load the CRS recommender
from recommender import explain

print("CRS recommender loaded successfully.")
# Out:
# CRS recommender loaded successfully.

# %%
# Demonstrate concept explanation
result = explain("MOSFET basics", 5)

print("EXPLANATION:\n")
print(result["explanation"])
# Out:
# EXPLANATION:
#
# Types:
#
# There are several types or classifications of field effect transistors , including: 1. **junction field effect transistor **: a type of fet where the gate terminal is connected to the channel through a p-n junction. the gate is not electrically isolated from the channel. 2. **insulated gate field effect transistor **: a type of fet where the gate terminal is electrically isolated from the channel by a thin layer of insulating material. this is also known as a metal oxide semiconductor field effect transistor . 3. **metal oxide semiconductor field effect transistor **: a type of igfet that uses a metal oxide gate electrode, which is electrically isolated from the channel by a thin layer of insulating material, usually silicon dioxide. 4. **depletion mode mosfet**: a type of mosfet where the channel is normally on, and the gate voltage is used to deplete the channel, reducing the current flow. 5. **enhancement mode mosfet**: a type of mosfet where the channel is normally off, and the gate voltage is used to create a channel, allowing current to flow. 6. **trench mosfet**: a type of mosfet where the channel is created in a trench or groove in the semiconductor material, allowing for higher current density and lower on-resistance. 7. **lateral mosfet**: a type of mosfet where the channel is created in a lateral direction, rather than vertically. 8. **vertical mosfet**: a type of mosfet where the channel is created in a vertical direction, allowing for higher current density and lower on-resistance. 9. **power mosfet**: a type of mosfet designed for high-power applications, such as motor control and power supplies. 10. **rf mosfet**: a type of mosfet designed for high-frequency applications, such as radio frequency amplifiers and switches. these are just a few examples of the many types and classifications of fets available. each type has its own unique characteristics and applications.
#
#
# Construction / Structure:
#
# The physical construction or internal structure of a mosfet is as follows: **basic structure:** a mosfet consists of three main terminals: gate , drain , and source . the device is built on a semiconductor substrate, typically silicon. **internal structure:** 1. **gate :** the gate is a metal electrode that is insulated from the semiconductor substrate by a thin layer of oxide . the gate is used to control the flow of current between the drain and source. 2. **channel:** the channel is a region of the semiconductor substrate where the current flows between the drain and source. the channel is created by applying a voltage to the gate. 3. **drain and source :** the drain and source are two metal electrodes that are connected to the ends of the channel. the drain is the terminal that is connected to the positive power supply, while the source is the terminal that is connected to the negative power supply. 4. **insulating layer:** the insulating layer is a thin layer of oxide that separates the gate from the semiconductor substrate. this layer prevents the gate from coming into contact with the channel and allows the gate to control the flow of current. 5. **gate insulation:** the gate insulation is a layer of oxide that surrounds the gate electrode. this layer prevents the gate from coming into contact with the semiconductor substrate and allows the gate to control the flow of current. **construction variations:** there are two main types of mosfets: depletion-type and enhancement-type. **depletion-type mosfet:** in a depletion-type mosfet, the channel is created by applying a negative voltage to the gate with respect to the source. this creates a depletion region in the channel, which reduces the conductivity of the channel. to switch the device "on", a positive voltage is applied to the gate, which creates a channel of high conductivity. **enhancement-type mosfet:** in an enhancement-type mosfet, the channel is not created until a positive voltage is applied to the gate with respect to the source. this creates a channel of high conductivity, allowing current to flow between the drain and source. **symbols and basic construction:** the symbols for mosfets are similar to those for jfets, with the addition of a triangle or a circle to indicate the type of mosfet . **p-channel and n-channel mosfets:** both p-channel and n-channel mosfets are available. the main difference between the two is the type of semiconductor material used in the channel. pmos devices use a p-type semiconductor material, while nmos devices use an n-type semiconductor material. **protection and handling:** mosfets are sensitive to static electricity and can be damaged if not handled carefully. to prevent damage, mosfets should be handled with anti-static wrist straps or stored in anti-static bags.

# %%
# Display related topics
print("RELATED TOPICS:\n")
for topic in result["related_topics"]:
    print("-", topic)
# Out:
# RELATED TOPICS:
#
# - Flip Flops Digital Electronics
# - Semiconductor Physics Basics
# - Operational Amplifiers Op Amps
# - Amplitude Modulation Am
# - Frequency Modulation Fm
# - Rectifiers Electronics

# %% [markdown]
# ## Conclusion
#
# The Concept Recommender System successfully demonstrates how semantic search and vector databases can be used to improve technical learning.
#
# ### Key Achievements
# - Time-aware explanations
# - Structured, exam-oriented content
# - Intelligent related-topic discovery
# - Scalable design with incremental updates
#
# ### Future Scope
# - Integration with PDF textbooks
# - User progress tracking
# - Personalized difficulty levels
# - Voice-based interaction
#
# This project shows practical application of AI concepts in education.
